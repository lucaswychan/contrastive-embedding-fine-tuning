# %%
from datasets import load_dataset

# %%
legal_bench = load_dataset("nguha/legalbench")

legal_bench
# Out:
# README.md:   0%|          | 0.00/68.0k [00:00<?, ?B/s]
# legalbench.py:   0%|          | 0.00/71.5k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/169k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 legal_bench = load_dataset("nguha/legalbench")
#       3 legal_bench
#
# File ~/anaconda3/envs/venv/lib/python3.10/site-packages/datasets/load.py:2132, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2127 verification_mode = VerificationMode(
#    2128     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2129 )
#    2131 # Create a dataset builder
# ...
